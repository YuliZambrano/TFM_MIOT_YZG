# %%
import pandas as pd
import requests
import re
import time
import random
from urllib.parse import quote, urlparse
from collections import Counter
from deep_translator import GoogleTranslator 


# ===============================================================
# 🔧 UTILIDADES GENERALES
# ===============================================================

def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower().strip()
    text = re.sub(r"[^a-zA-Z0-9áéíóúñ ]", " ", text)
    return re.sub(r"\s+", " ", text).strip()


def translate_to_en(text):
    """Traducción de texto con manejo de errores."""
    try:
        # Solo traduce si la longitud es razonable para evitar abusos o errores
        if len(text.split()) < 3 and len(text) < 15:
            return text
        return GoogleTranslator(source='auto', target='en').translate(text)
    except:
        return text


def extract_keywords(title, description, k=5):
    """Extrae palabras clave largas y únicas."""
    text = clean_text((title or "") + " " + (description or ""))
    stop = {"de", "del", "la", "el", "y", "en", "por", "con", "los", "las", "un", "una", "o", "a", "para", "es", "que", "se", "como", "mas"}
    words = [w for w in text.split() if len(w) > 4 and w not in stop]
    
    # Usa Counter para obtener las palabras más frecuentes
    word_counts = Counter(words)
    # Selecciona las palabras más comunes hasta el límite k
    return [word for word, count in word_counts.most_common(k)]


def get_quoted_query(query, quoted):
    """Genera la cadena de consulta con o sin comillas."""
    query_clean = query.replace('"', '').strip()
    if not query_clean: return None
    if quoted:
        # Búsqueda exacta (frase)
        return quote(f'"{query_clean}"')
    else:
        # Búsqueda amplia (palabras separadas)
        return quote(query_clean)


# ===============================================================
# FUENTES DE REUTILIZACIÓN (Búsqueda por Contenido)
# ===============================================================

# ---------- CROSSREF ----------
def search_crossref(query, quoted=True):
    quoted_query = get_quoted_query(query, quoted)
    if not quoted_query: return []
    url = f"https://api.crossref.org/works?query.full={quoted_query}&rows=10"
    try:
        r = requests.get(url, timeout=15).json()
        items = r.get("message", {}).get("items", [])
        results = []
        for it in items:
            results.append({
                "source": "crossref",
                "external_id": it.get("DOI"),
                "title": " | ".join(it.get("title", [])),
                "url": it.get("URL"),
                "date": it.get("created", {}).get("date-time", "")
            })
        return results
    except:
        return []


# ---------- OPENALEX ----------
def search_openalex(query, quoted=True):
    quoted_query = get_quoted_query(query, quoted)
    if not quoted_query: return []
    # default.search busca en título y abstract.
    url = f"https://api.openalex.org/works?filter=default.search:{quoted_query}&per-page=10"
    try:
        r = requests.get(url, timeout=15).json()
        results = []
        for it in r.get("results", []):
            results.append({
                "source": "openalex",
                "external_id": it.get("id"),
                "title": it.get("title"),
                "url": it.get("doi"),
                "date": it.get("publication_date")
            })
        return results
    except:
        return []


# ---------- ZENODO ----------
def search_zenodo(query, quoted=True):
    quoted_query = get_quoted_query(query, quoted)
    if not quoted_query: return []
    url = f"https://zenodo.org/api/records/?q={quoted_query}&size=10"
    try:
        r = requests.get(url, timeout=15).json()
        hits = r.get("hits", {}).get("hits", [])
        results = []
        for it in hits:
            md = it.get("metadata", {})
            results.append({
                "source": "zenodo",
                "external_id": it.get("id"),
                "title": md.get("title"),
                "url": md.get("doi"),
                "date": md.get("publication_date")
            })
        return results
    except:
        return []


# ---------- GITHUB - SIN TOKEN ----------
def search_github(query, is_uri=False):
    # GitHub no necesita el parámetro `quoted` en el mismo sentido, se maneja en q_final
    
    headers = {"Accept": "application/vnd.github.v3.text-match+json", 
               'User-Agent': 'TFM-Data-Reuse-Analyzer/1.0'}

    if is_uri:
        q_final = f'"{query}" in:file extension:md,ipynb,json,py'
    elif "." in query:
        q_final = f'filename:"{query}" in:path'
    else:
        # Búsqueda por palabras clave sin comillas para ser amplio
        q_final = query 
        if len(q_final.split()) > 1:
            q_final = f'"{q_final}" in:readme' # Si es una frase, la busca en readme
        else:
            q_final = f'{q_final} in:readme'
        
    url = f"https://api.github.com/search/code?q={quote(q_final)}&per_page=10"
    
    try:
        r = requests.get(url, headers=headers, timeout=15).json()
        items = r.get("items", [])
        
        # 🚨 Manejo de Rate Limit (CRÍTICO sin Token)
        if 'message' in r and 'rate limit' in r['message']:
            print("🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...")
            time.sleep(60) 
            return []
        if 'message' in r and r['message'] == 'Not Found': 
            return []
            
        results = []
        for it in items:
            repo = it.get("repository", {})
            results.append({
                "source": "github",
                "external_id": repo.get("full_name"),
                "title": it.get("name"),
                "url": it.get("html_url"),
                "date": repo.get("pushed_at") or repo.get("created_at", "")
            })
        return results
    except Exception:
        return []


# ---------- KAGGLE (Scraping de datasets) ----------
def search_kaggle(query, quoted=True):
    # Kaggle API no usa el concepto de quoted/unquoted, la URL de búsqueda es simple
    query_clean = get_quoted_query(query, False) # Solo quotea sin comillas
    if not query_clean: return []
    
    try:
        url = f"https://www.kaggle.com/datasets?search={query_clean}"
        r = requests.get(url, timeout=10, headers={'User-Agent': 'Mozilla/5.0'})
        html = r.text
        titles = re.findall(r'data-testid="title">(.*?)</span>', html)
        links  = re.findall(r'href="(/datasets/[^"]+)"', html)

        results = []
        for i, t in enumerate(titles[:5]):
            link = links[i] if i < len(links) else ""
            results.append({
                "source": "kaggle",
                "external_id": "",
                "title": clean_text(t),
                "url": "https://www.kaggle.com" + link if link else "",
                "date": ""
            })
        return results
    except:
        return []


# ---------- CORDIS ----------
def search_cordis(query, quoted=True):
    quoted_query = get_quoted_query(query, quoted)
    if not quoted_query: return []
    
    try:
        url = f"https://cordis.europa.eu/api/search?q={quoted_query}&num=5"
        r = requests.get(url, timeout=15).json()
        results = []
        for it in r.get("projects", []):
            results.append({
                "source": "cordis",
                "external_id": it.get("id"),
                "title": it.get("title"),
                "url": f"https://cordis.europa.eu/project/id/{it.get('id')}",
                "date": it.get("startDate", "")
            })
        return results
    except:
        return []


# ===============================================================
# FUNCIÓN PRINCIPAL DE BÚSQUEDA JERÁRQUICA (REFUERZO DE KEYWORDS)
# ===============================================================

def search_reuse(r):

    dataset_uri = r["dataset_uri"]
    title = r["title"]
    #  CRÍTICO: Necesitamos la descripción para extraer palabras clave.
    description = r["description"] 
    file_names = r["file_names"]

    queries = []

    # 1. ALTA PRECISIÓN: URI Exacta
    queries.append({"q": dataset_uri, "match_type": "URI_STRICT", "is_uri": True, "quoted": True})

    # 2. MEDIA PRECISIÓN: Nombres de archivo únicos
    if isinstance(file_names, str):
        file_names = eval(file_names) # Convierte la cadena de lista a lista real si viene de Excel
    
    for fn in file_names:
        if len(fn) > 8 and '.' in fn:
            queries.append({"q": fn, "match_type": "FILENAME", "is_uri": False, "quoted": True})

    # 3. BAJA PRECISIÓN: Título Exacto (como frase)
    title_clean = clean_text(title)
    if len(title_clean.split()) > 3:
        queries.append({"q": title_clean, "match_type": "TITLE_EXACT", "is_uri": False, "quoted": True})

    # 4.  NUEVO: BAJA PRECISIÓN (AMPLIA): Palabras clave traducidas (crucial para OpenAlex/Crossref)
    keywords_es = extract_keywords(title, description, k=5)
    
    if keywords_es:
        # Busca las palabras clave combinadas, traducidas y SIN comillas para búsqueda amplia
        keywords_en = " ".join([translate_to_en(k) for k in keywords_es])
        
        # Debe haber al menos dos palabras clave para una búsqueda significativa
        if keywords_en and len(keywords_en.split()) > 1:
            queries.append({"q": keywords_en, "match_type": "KEYWORD_BROAD", "is_uri": False, "quoted": False})
            
    results = []
    
    sources = [
        (search_openalex, "openalex"),
        (search_crossref, "crossref"),
        (search_zenodo, "zenodo"),
        (search_github, "github"),
        (search_kaggle, "kaggle"),
        (search_cordis, "cordis"),
    ]

    for query_data in queries:
        q = query_data["q"]
        match_type = query_data["match_type"]
        is_uri = query_data["is_uri"]
        quoted = query_data["quoted"]
        
        if not q or not str(q).strip(): continue

        for fn, src in sources:
            
            # GitHub tiene un manejo especial de la búsqueda
            if src == "github":
                hits = fn(q, is_uri=is_uri)
            else:
                # El resto de fuentes usan el flag 'quoted'
                hits = fn(q, quoted=quoted)

            for h in hits:
                h["match_type"] = match_type
                results.append(h)

        time.sleep(0.5 + random.random() * 0.5)

    return results


# ===============================================================
# MAIN PUNTO 2
# ===============================================================

def main():

    #  NOTA: AQUI LOS ARCHIVOS
    INPUT = "Punto1_NOMBREARCHIVORESULTADO.xlsx"                # ARCHIVO RESULTADO DEL SCRIPT 1
    OUTPUT = "Punto2_NOMBREARCHIVORESULTADO.xlsx"   # ARCHIVO QUE RESULTADO DE ESTE SCRIPT 2

    try:
        df = pd.read_excel(INPUT)
    except FileNotFoundError:
        print(f"Error: No se encontró el archivo de entrada '{INPUT}'. Asegúrate de ejecutar el Punto 1 y que el archivo exista.")
        return

    #  CRÍTICO: Asegurarse de que las columnas necesarias existan
    required_cols = ["dataset_uri", "title", "description", "file_names", "category", "issued"]
    if not all(col in df.columns for col in required_cols):
        print(f"Error: El archivo de entrada '{INPUT}' no contiene todas las columnas requeridas para la búsqueda de reutilización ({', '.join(required_cols)}).")
        return

    rows = []
    counter = Counter()

    print("\n Iniciando búsqueda OPTIMIZADA y REFORZADA de reutilización (V5)...\n")
    print(f"Total de datasets a procesar: {len(df)}")

    for idx, r in df.iterrows():

        print(f"[{idx+1}/{len(df)}] → Buscando para: {r['title']}")

        hits = search_reuse(r)

        for h in hits:
            rows.append({
                "dataset_uri": r["dataset_uri"],
                "title_dataset": r["title"],
                "category": r["category"],
                "issued": r["issued"],
                
                "source": h.get("source"),
                "external_id": h.get("external_id"),
                "match_type": h.get("match_type"),
                "source_title": h.get("title"),
                "url": h.get("url"),
                "date": h.get("date")
            })

            counter[h.get("source")] += 1
        
    out = pd.DataFrame(rows)
    
    # Desambiguación: Prioriza la URI_STRICT y elimina duplicados de huella
    match_order = {'URI_STRICT': 0, 'FILENAME': 1, 'TITLE_EXACT': 2, 'KEYWORD_BROAD': 3}
    out_final = out.sort_values(by='match_type', key=lambda x: x.map(match_order), ascending=True)
    out_final = out_final.drop_duplicates(subset=['dataset_uri', 'external_id', 'source'], keep='first')
    
    out_final.to_excel(OUTPUT, index=False)

    print("\n Archivo generado correctamente →", OUTPUT)

    print("\n Recuento de huellas únicas por fuente:\n")
    for src, cnt in out_final["source"].value_counts().items():
        print(f"  {src}: {cnt} huellas únicas")


if __name__ == "__main__":
    main()
# Out:
# 🔎 Iniciando búsqueda OPTIMIZADA y REFORZADA de reutilización (V5)...
#
# Total de datasets a procesar: 118
# [1/118] → Buscando para: Zonificación de transporte
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [2/118] → Buscando para: Vehículos de transporte sanitario
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [3/118] → Buscando para: Oficinas de Gestión Tarjeta Transporte Público
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [4/118] → Buscando para: Puntos de venta de títulos de transporte: Estancos
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [5/118] → Buscando para: Aparcamientos de disuasión ligados al transporte público en la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [6/118] → Buscando para: Anclajes de bicicletas ligados al Sistema de Transporte Público de la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [7/118] → Buscando para: Zonificación de transporte ZT84 de la EDM2018 y ESM2014
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [8/118] → Buscando para: Topología de la Red de Autobuses Interurbanos
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [9/118] → Buscando para: Oferta planificada de la Red de Cercanías Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [10/118] → Buscando para: Topología de la Red de Cercanías Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [11/118] → Buscando para: Oferta planificada de la Red de Metro Ligero
# [12/118] → Buscando para: Oferta planificada de la Red de Metro
# [13/118] → Buscando para: Topología de la Red de Metro
# [14/118] → Buscando para: reB: Red de estacionamiento de bicicletas
# [15/118] → Buscando para: Oferta planificada de la Red de Autobuses Interurbanos
# [16/118] → Buscando para: Oferta planificada de la Red de Autobuses Urbanos del resto de municipios de la Comunidad de Madrid
# [17/118] → Buscando para: Oferta planificada de la Red de Autobuses Urbanos de Madrid - EMT
# [18/118] → Buscando para: Topología de la Red de Autobuses Urbanos de Madrid - EMT
# [19/118] → Buscando para: Topología de la Red de Metro Ligero / Tranvía
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [20/118] → Buscando para: Bases de los sistemas públicos de préstamo de bicicletas en la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [21/118] → Buscando para: Resultados de la EDM 2018
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [22/118] → Buscando para: Registro de Agentes Inmobiliarios (RAIN)
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [23/118] → Buscando para: Viviendas de la Agencia de Vivienda Social
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [24/118] → Buscando para: Transportistas de residuos de la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [25/118] → Buscando para: Instalaciones de gestión de residuos de la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [26/118] → Buscando para: Programas excelencia innovacion
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [27/118] → Buscando para: Opciones lingüisticas en los centros educativos de la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [28/118] → Buscando para: Actividades extraescolares institucionales en centros educativos de la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [29/118] → Buscando para: Centros educativos de la comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [30/118] → Buscando para: Registro de centros de atención social
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [31/118] → Buscando para: Registro de servicios de atención social
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [32/118] → Buscando para: Registro de Explotaciones Ganaderas de la Comunidad de Madrid
# [33/118] → Buscando para: Histórico de Relación de Puestos de Trabajo
# [34/118] → Buscando para: Relación de Puestos de Trabajo
# [35/118] → Buscando para: Declaraciones responsables de actividad de viviendas de uso turístico de la Comunidad de Madrid presentadas
# [36/118] → Buscando para: Sugerencias, quejas y agradecimientos (año en curso)
# [37/118] → Buscando para: Sugerencias, quejas y agradecimientos (historico)
# [38/118] → Buscando para: Red de Calidad del Aire. Datos del mes en curso
# [39/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid 2019
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [40/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid 2021
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [41/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid 1995
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [42/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid 1999
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [43/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid mayo 2003
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [44/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid octubre 2003
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [45/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid 2007
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [46/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid 2015
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [47/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid 2023
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [48/118] → Buscando para: Datos electorales elecciones autonómicas Comunidad de Madrid 2011
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [49/118] → Buscando para: Red de Calidad del Aire. Datos meteorológicos horarios desde 2020.
# [50/118] → Buscando para: Red de Calidad del Aire. Datos del día en curso
# [51/118] → Buscando para: Red de Calidad del Aire. Datos horarios desde 2005
# [52/118] → Buscando para: Red de calidad del aire. Datos meteorológicos del mes en curso.
# [53/118] → Buscando para: Covid 19 -TIA Zonas Básicas de Salud
# [54/118] → Buscando para: Covid 19 -TIA por Municipios y Distritos de Madrid
# [55/118] → Buscando para: Covid 19 -TIA para población de 60 y más años de edad por Zonas Básicas de Salud
# [56/118] → Buscando para: Covid 19 -TIA para población de 60 y más años de edad por Municipios y Distritos de Madrid
# [57/118] → Buscando para: Niveles de polen por tipo polínico
# [58/118] → Buscando para: Inventario de Emisiones a la Atmósfera de la Comunidad de Madrid (nomenclatura SNAP)
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [59/118] → Buscando para: Registro de Certificados de Eficiencia Energética de Edificios
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [60/118] → Buscando para: Histórico de mediciones de polen
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [61/118] → Buscando para: Oficinas de farmacia
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [62/118] → Buscando para: Cursos de Formación Profesional para el Empleo
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [63/118] → Buscando para: Información sobre Escuelas de Tiempo Libre autorizadas
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [64/118] → Buscando para: Distritos del Municipio de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [65/118] → Buscando para: Captadores de polen
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [66/118] → Buscando para: Barrios del Municipio de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [67/118] → Buscando para: Agenda de Gobierno
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [68/118] → Buscando para: Información sobre albergues y refugios juveniles de la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [69/118] → Buscando para: Cursos de Educación no formal de la Escuela Pública de Animación y Educación Juvenil
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [70/118] → Buscando para: Tributos cedidos de gestión propia. Ingresos del ejercicio corriente
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [71/118] → Buscando para: Residentes en la Comunidad de Madrid por Lugar de Nacimiento
# [72/118] → Buscando para: Municipios de la Comunidad de Madrid
# [73/118] → Buscando para: Defunciones en la Comunidad de Madrid por nacionalidad
# [74/118] → Buscando para: Defunciones en la Comunidad de Madrid por grupos de edad
# [75/118] → Buscando para: Encuesta sobre la percepción social del patrimonio cultural en la Comunidad de Madrid 2022
# [76/118] → Buscando para: Encuesta sobre la percepción social del patrimonio cultural en la Comunidad de Madrid 2020
# [77/118] → Buscando para: Nacimientos en la Comunidad de Madrid por provincia de nacimiento de la madre
# [78/118] → Buscando para: Nacimientos en la Comunidad de Madrid por grupos de edad de la madre
# [79/118] → Buscando para: Defunciones en la Comunidad de Madrid por provincia de nacimiento
# [80/118] → Buscando para: Nacimientos en la Comunidad de Madrid por nacionalidad de la madre
# [81/118] → Buscando para: Registro de Establecimientos y Servicios Biocidas
# [82/118] → Buscando para: Registro de Establecimientos de Adorno Corporal
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [83/118] → Buscando para: Censo y calificación de las zonas de baño
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [84/118] → Buscando para: Registro de establecimientos de comercio al por menor de la carne en la Comunidad de Madrid.
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [85/118] → Buscando para: Registro de laboratorios de análisis de alimentos y aguas de consumo ubicados en otras Comunidades autónomas comunicados en la Comunidad de Madrid.
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [86/118] → Buscando para: Registro de laboratorios de análisis de alimentos y aguas de consumo autorizados en la Comunidad de Madrid.
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [87/118] → Buscando para: Desfibriladores externos fuera del ámbito sanitario
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [88/118] → Buscando para: Establecimientos de productos sanitarios
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [89/118] → Buscando para: Centros, servicios y establecimientos sanitarios
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [90/118] → Buscando para: Participación en actividades de educación ambiental
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [91/118] → Buscando para: Personal de la Administración de Justicia
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [92/118] → Buscando para: Convalidación de inversiones en medio ambiente
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [93/118] → Buscando para: Autorizaciones Ambientales Integradas de la Comunidad de Madrid
# [94/118] → Buscando para: Repoblaciones forestales
# [95/118] → Buscando para: Espacios protegidos
# [96/118] → Buscando para: Hábitats de la Comunidad de Madrid
# [97/118] → Buscando para: Concesiones de etiqueta ecológica
# [98/118] → Buscando para: Red de Calidad del Aire. Estaciones
# [99/118] → Buscando para: Centro de Recuperación de Animales Silvestres de la Comunidad de Madrid (CRAS)
# [100/118] → Buscando para: Registro de instalaciones emisoras de COV (RIECOV)
# [101/118] → Buscando para: Red de Calidad del Aire. Municipios por zonas
# [102/118] → Buscando para: Tratamiento de residuos peligrosos
# [103/118] → Buscando para: Recuperación de vidrio
# [104/118] → Buscando para: Recuperación de residuos domésticos
# [105/118] → Buscando para: Generación de residuos domésticos
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [106/118] → Buscando para: Producción ecológica
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [107/118] → Buscando para: Actos administrativos en materia de suelos contaminados
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [108/118] → Buscando para: Sociedades Agrarias de Transformación
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [109/118] → Buscando para: Parcelas publicadas en el Portal del Suelo 4.0
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [110/118] → Buscando para: Registro de Asociaciones de la Comunidad de Madrid
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [111/118] → Buscando para: Residentes en la Comunidad de Madrid por Rango de Edad
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# [112/118] → Buscando para: Residentes en la Comunidad de Madrid por Nacionalidad
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
# 🚨 Límite de tasa de GitHub alcanzado (sin token). Pausando 60s...
