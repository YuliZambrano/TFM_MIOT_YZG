# %%
import pandas as pd
import requests
import re
import time
import random
from urllib.parse import quote, urlparse
from collections import Counter

# ==========================================================
# CONFIGURACIÓN
# ==========================================================

INPUT_FILE  = "Punto1_NOMBREARCHIVORESULTADO.xlsx"                # ARCHIVO RESULTADO DEL SCRIPT 1
OUTPUT_FILE = "Punto2_NOMBREARCHIVORESULTADO.xlsx"               # ARCHIVO QUE RESULTADO DE ESTE SCRIPT 2
PORTAL_NAME = "NOMBRE DEL PORTAL"                               # NOMBRE DEL PORTAL

# AQUI PUEDES USAR TU TOKEN DE GitHub, ponlo aquí para mejores resultados
GITHUB_TOKEN = None  # "EJEMPLO_xxxxxxxxxxxxxxxxxxxxx"


# ==========================================================
# UTILIDADES
# ==========================================================

def clean_text(text: str) -> str:
    if not isinstance(text, str):
        return ""
    text = text.strip().lower()
    text = re.sub(r"\s+", " ", text)
    return text


def extract_dataset_id(dataset_uri: str) -> str:
    try:
        return dataset_uri.rstrip("/").split("/")[-1]
    except:
        return ""


def extract_domain(dataset_uri: str) -> str:
    try:
        return urlparse(dataset_uri).netloc
    except:
        return ""


def extract_file_tokens(download_url: str):
    """
    A partir de la columna download_url genera tokens fuertes:
    nombres de ficheros sin extensión (transporte-bus, paradas-autobus, Ferris, etc.).
    """
    tokens = set()
    if not isinstance(download_url, str):
        return tokens

    parts = [p.strip() for p in download_url.split(";") if p.strip()]
    for p in parts:
        # nombre de archivo
        fname = p.split("/")[-1]
        if not fname:
            continue
        base = fname.split(".")[0]  # sin extensión
        base_clean = clean_text(base)
        if base_clean:
            tokens.add(base_clean)
    return tokens


def build_strong_tokens(dataset_uri: str, title: str, download_url: str):
    """
    Construye un conjunto de tokens "fuertes" para detectar reutilización real:
    - slug del dataset (último segmento de la URI)
    - nombres de ficheros de descarga (sin extensión)
    - título del dataset normalizado completo
    """
    tokens = set()

    # slug
    slug = extract_dataset_id(dataset_uri)
    slug_clean = clean_text(slug)
    if slug_clean:
        tokens.add(slug_clean)

    # título completo normalizado
    title_clean = clean_text(title)
    if title_clean:
        tokens.add(title_clean)

    # tokens de archivos
    tokens |= extract_file_tokens(download_url)

    return tokens


# ==========================================================
# FUENTES DE REUTILIZACIÓN
# (todas se consultan con identificadores fuertes)
# ==========================================================

def search_crossref(query: str):
    url = f"https://api.crossref.org/works?query={quote(query)}&rows=5"
    try:
        r = requests.get(url, timeout=10).json()
        items = r.get("message", {}).get("items", [])
        results = []
        for it in items:
            results.append({
                "source": "crossref",
                "external_id": it.get("DOI"),
                "title": " | ".join(it.get("title", [])),
                "url": it.get("URL"),
                "date": it.get("created", {}).get("date-time", "")
            })
        return results
    except:
        return []


def search_openalex(query: str):
    # Lo mantenemos por completitud, pero será filtrado igual que crossref
    url = f"https://api.openalex.org/works?filter=title.search:{quote(query)}&per-page=5"
    try:
        r = requests.get(url, timeout=10).json()
        results = []
        for it in r.get("results", []):
            results.append({
                "source": "openalex",
                "external_id": it.get("id"),
                "title": it.get("title"),
                "url": it.get("doi"),
                "date": it.get("publication_date")
            })
        return results
    except:
        return []


def search_zenodo(query: str):
    url = f"https://zenodo.org/api/records/?q={quote(query)}&size=5"
    try:
        r = requests.get(url, timeout=10).json()
        hits = r.get("hits", {}).get("hits", [])
        results = []
        for it in hits:
            md = it.get("metadata", {})
            results.append({
                "source": "zenodo",
                "external_id": it.get("id"),
                "title": md.get("title"),
                "url": md.get("doi"),
                "date": md.get("publication_date")
            })
        return results
    except:
        return []


def search_github(query: str):
    headers = {"Accept": "application/vnd.github+json"}
    if GITHUB_TOKEN:
        headers["Authorization"] = f"token {GITHUB_TOKEN}"

    q = query.strip()
    if len(q) > 80:
        q = q[:80]

    url = f"https://api.github.com/search/code?q={quote(q)}+in:file&per_page=5"
    try:
        r = requests.get(url, headers=headers, timeout=10).json()
        items = r.get("items", [])
        results = []
        for it in items:
            repo = it.get("repository", {})
            results.append({
                "source": "github",
                "external_id": repo.get("full_name"),
                "title": it.get("name"),
                "url": it.get("html_url"),
                "date": repo.get("pushed_at") or repo.get("created_at", "")
            })
        return results
    except:
        return []


def search_kaggle(query: str):
    try:
        url = f"https://www.kaggle.com/datasets?search={quote(query)}"
        r = requests.get(url, timeout=10)
        html = r.text

        titles = re.findall(r'data-testid="title">(.*?)</span>', html)
        links  = re.findall(r'href="(/datasets/[^"]+)"', html)

        results = []
        for i, t in enumerate(titles[:5]):
            url_rel = links[i] if i < len(links) else ""
            results.append({
                "source": "kaggle",
                "external_id": "",
                "title": t,
                "url": "https://www.kaggle.com" + url_rel if url_rel else "",
                "date": ""
            })
        return results
    except:
        return []


def search_cordis(query: str):
    try:
        url = f"https://cordis.europa.eu/api/search?q={quote(query)}&num=5"
        r = requests.get(url, timeout=10).json()
        projects = r.get("projects") or r.get("results") or []
        results = []
        for it in projects:
            results.append({
                "source": "cordis",
                "external_id": it.get("id"),
                "title": it.get("title", ""),
                "url": str(it.get("rcn", "")),
                "date": it.get("startDate", "")
            })
        return results
    except:
        return []


def search_google_play(query: str):
    try:
        url = f"https://play.google.com/store/search?q={quote(query)}&c=apps"
        r = requests.get(url, timeout=10)
        html = r.text.lower()
        apps = re.findall(r'\"title\":\{\"label\":\"(.*?)\"', html)
        return [{
            "source": "google_play",
            "external_id": "",
            "title": a,
            "url": "",
            "date": ""
        } for a in apps[:5]]
    except:
        return []


def search_appstore(query: str):
    try:
        url = f"https://apps.apple.com/es/search?term={quote(query)}"
        r = requests.get(url, timeout=10)
        html = r.text
        apps = re.findall(
            r'<h3 class="we-truncate we-truncate--single-line we-truncate--interactive we-truncate--multi-line-medium">([^<]+)</h3>',
            html
        )
        return [{
            "source": "app_store",
            "external_id": "",
            "title": a,
            "url": "",
            "date": ""
        } for a in apps[:5]]
    except:
        return []


# ==========================================================
# FILTRO DE REUTILIZACIÓN REAL (incluye Crossref/Zenodo)
# ==========================================================

def is_real_reuse(hit: dict,
                  dataset_uri: str,
                  strong_tokens: set,
                  portal_markers: set,
                  query_used: str) -> bool:
    """
    Devuelve True SOLO si el resultado hace referencia real al dataset:
    - contiene la URL del dataset, o
    - contiene algún token fuerte (slug, nombre de fichero, título normalizado), o
    - contiene algún marcador del portal (datosabiertos.regiondemurcia.es, datos.lorca.es, nexo.carm.es)
    """

    source = hit.get("source", "")
    title  = clean_text(hit.get("title", "") or "")
    url    = clean_text(hit.get("url", "") or "")
    extid  = clean_text(str(hit.get("external_id", "") or ""))
    q      = clean_text(query_used or "")

    full_text = " ".join([title, url, extid, q])

    ds_uri  = clean_text(dataset_uri or "")

    # 1) URL EXACTA del dataset (muy fuerte)
    if ds_uri and ds_uri in full_text:
        return True

    # 2) Marcadores de portal + slug / token fuerte
    for mk in portal_markers:
        mk_clean = clean_text(mk)
        if mk_clean and mk_clean in full_text:
            # si además aparece algún token fuerte, es reutilización clara
            for tok in strong_tokens:
                tok_clean = clean_text(tok)
                if tok_clean and tok_clean in full_text:
                    return True
            # o, si el propio marcador es muy específico (ej. datos.lorca.es/calle-cortada)
            if "/" in mk and mk_clean in full_text:
                return True

    # 3) Tokens fuertes solos (slug, nombres de fichero, título exacto)
    for tok in strong_tokens:
        tok_clean = clean_text(tok)
        if tok_clean and tok_clean in full_text:
            return True

    # Si no pasa ningún criterio, NO consideramos reutilización
    return False


# ==========================================================
# CONSTRUCCIÓN DE QUERIES POR DATASET
# ==========================================================

def build_queries(dataset_uri: str,
                  strong_tokens: set,
                  portal_markers: set):
    """
    Construye una lista corta de queries "fuertes":
    - la URI completa del dataset
    - el dominio
    - algunos tokens fuertes (slug, nombres de fichero)
    - marcadores de portal
    """

    queries = []

    ds_uri = dataset_uri.strip()
    if ds_uri:
        queries.append((ds_uri, "URI_STRICT"))

    domain = extract_domain(dataset_uri)
    if domain:
        queries.append((domain, "DOMAIN_STRICT"))

    # tokens fuertes (slug + nombres fichero + título normalizado)
    # limitamos a 3 para no disparar APIs
    for tok in list(strong_tokens)[:3]:
        if tok:
            queries.append((tok, "TOKEN_STRONG"))

    # marcadores del portal (datosabiertos.regiondemurcia.es, datos.lorca.es, nexo.carm.es)
    for mk in portal_markers:
        if mk:
            queries.append((mk, "PORTAL_MARKER"))

    # eliminar duplicados manteniendo orden
    seen = set()
    final_queries = []
    for q, mt in queries:
        q_norm = q.strip()
        if not q_norm:
            continue
        key = (q_norm, mt)
        if key not in seen:
            seen.add(key)
            final_queries.append((q_norm, mt))

    return final_queries[:8]


# ==========================================================
# BÚSQUEDA MULTIFUENTE POR DATASET
# ==========================================================

def search_reuse(dataset_uri: str,
                 title: str,
                 download_url: str):
    strong_tokens = build_strong_tokens(dataset_uri, title, download_url)

    # marcadores globales del portal Murcia
    portal_markers = {
        "https://datosabiertos.regiondemurcia.es",
        "datosabiertos.regiondemurcia.es",
        "http://datos.lorca.es",
        "datos.lorca.es",
        "http://nexo.carm.es",
        "nexo.carm.es",
    }

    queries = build_queries(dataset_uri, strong_tokens, portal_markers)

    results = []

    sources = [
        (search_crossref,    "crossref"),
        (search_openalex,    "openalex"),
        (search_zenodo,      "zenodo"),
        (search_github,      "github"),
        (search_kaggle,      "kaggle"),
        (search_cordis,      "cordis"),
        (search_google_play, "google_play"),
        (search_appstore,    "app_store"),
    ]

    for q, match_type in queries:
        for fn, src in sources:
            hits = fn(q)
            for h in hits:
                if is_real_reuse(h, dataset_uri, strong_tokens, portal_markers, q):
                    h["match_type"] = match_type
                    h["query_used"] = q
                    results.append(h)
        # Pausa para no abusar de las APIs
        time.sleep(0.25 + random.random() * 0.25)

    return results


# ==========================================================
# MAIN
# ==========================================================

def main():
    df = pd.read_excel(INPUT_FILE)

    rows = []
    counter = Counter()

    print(f"\n🔎 Iniciando búsqueda de reutilización REAL (con Crossref/Zenodo filtrados) – {PORTAL_NAME}\n")

    for _, r in df.iterrows():
        dataset_uri  = r.get("dataset_uri", "")
        title        = r.get("title", "")
        download_url = r.get("download_url", "")
        issued       = r.get("issued")

        print(f" → Buscando reutilización para: {title}")

        hits = search_reuse(dataset_uri, title, download_url)

#SE PUEDEN MODIFICAR LOS RETORNOS RESULTADOS SIEMPRE QUE LOS DEFINAS EN EL SCRIPT        
        for h in hits:
            rows.append({
                "dataset_uri":   dataset_uri,
                "title_dataset": title,
                "issued":        issued,
                "source":        h.get("source"),
                "external_id":   h.get("external_id"),
                "match_type":    h.get("match_type"),
                "query_used":    h.get("query_used"),
                "source_title":  h.get("title"),
                "url":           h.get("url"),
                "date":          h.get("date"),
            })
            counter[h.get("source")] += 1

    out = pd.DataFrame(rows)
    out.to_excel(OUTPUT_FILE, index=False)

    print(f"\n Archivo generado correctamente → {OUTPUT_FILE}\n")
    print(f" Recuento de huellas de reutilización REAL (filtradas) – {PORTAL_NAME}:\n")
    if not counter:
        print("  (No se han encontrado huellas estrictas de reutilización en ninguna fuente)")
    else:
        for src, cnt in counter.items():
            print(f"  {src}: {cnt} coincidencias")


if __name__ == "__main__":
    main()
# Out:
# 🔎 Iniciando búsqueda de reutilización REAL (con Crossref/Zenodo filtrados) – Región de Murcia
#
#  → Buscando reutilización para: Líneas de autobús
#  → Buscando reutilización para: Carriles bici
#  → Buscando reutilización para: Paradas de autobús
#  → Buscando reutilización para: Calle cortada
#  → Buscando reutilización para: Estrechamiento de calzada
#  → Buscando reutilización para: Paradas de taxis
#  → Buscando reutilización para: Aparcamientos públicos
#  → Buscando reutilización para: Taxis
#  → Buscando reutilización para: Ferris
#  → Buscando reutilización para: Aeropuertos
#  → Buscando reutilización para: La bicicleta en Lorca
#  → Buscando reutilización para: Estaciones de Autobuses
#  → Buscando reutilización para: Coches de Alquiler
#  → Buscando reutilización para: Estaciones de Tren
#  → Buscando reutilización para: Contenedores de LIMUSA
#  → Buscando reutilización para: Contenedores de LIMUSA
#  → Buscando reutilización para: Contenedores de LIMUSA
#  → Buscando reutilización para: Contenedores de LIMUSA
#  → Buscando reutilización para: Contenedores de LIMUSA
#  → Buscando reutilización para: Relación de vehículos Municipales
#  → Buscando reutilización para: Reservas de espacio
#  → Buscando reutilización para: Paradas de taxi
#  → Buscando reutilización para: Parkings públicos
#  → Buscando reutilización para: Otras incidencias de tráfico
#  → Buscando reutilización para: Smart5k - Aparcamiento - Movilidad Reducida - Pliego
#  → Buscando reutilización para: Smart5k - Aparcamiento - Movilidad Reducida - Albudeite
#  → Buscando reutilización para: Smart5k - Aparcamiento - Movilidad Reducida - Aledo
#  → Buscando reutilización para: Smart5k - Aparcamiento - Movilidad Reducida - Ulea
#  → Buscando reutilización para: Smart5k - Aparcamiento - Movilidad Reducida - Ricote
#  → Buscando reutilización para: Smart5k - Aparcamiento - Movilidad Reducida - Ojos
#  → Buscando reutilización para: Estaciones de tren y autobuses
#  → Buscando reutilización para: Smart5k - Aparcamiento - Movilidad Reducida - Campos del Rio
#  → Buscando reutilización para: Smart5k - Aparcamiento - Movilidad Reducida - Villanueva
#  → Buscando reutilización para: Plazas de parking para personas con movilidad reducida
#  → Buscando reutilización para: Smart10k - Aparcamiento - Movilidad Reducida - Moratalla
#  → Buscando reutilización para: Smart10k - Aparcamiento - Movilidad Reducida - Lorqui
#  → Buscando reutilización para: Smart10k - Aparcamiento - Movilidad Reducida - Blanca
#  → Buscando reutilización para: Smart10k - Aparcamiento - Movilidad Reducida - Librilla
#  → Buscando reutilización para: Agenda del alcalde y concejales en 2020
#  → Buscando reutilización para: Presupuesto 2021 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Presupuesto de gastos 2022 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Presupuesto de gastos 2023 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Presupuesto 2019 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Contratos menores CARM 2017
#  → Buscando reutilización para: Contratos menores CARM 2016
#  → Buscando reutilización para: Contratos menores CARM 2015
#  → Buscando reutilización para: Presupuesto 2018 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Presupuesto 2020 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Contratos menores CARM 2014
#  → Buscando reutilización para: Presupuesto gastos 2015
#  → Buscando reutilización para: Presupuesto gastos 2017
#  → Buscando reutilización para: Presupuesto gastos 2019
#  → Buscando reutilización para: Presupuesto gastos 2019
#  → Buscando reutilización para: Presupuesto gastos 2019
#  → Buscando reutilización para: Presupuesto gastos 2019
#  → Buscando reutilización para: Presupuesto gastos 2017
#  → Buscando reutilización para: Presupuesto gastos 2019
#  → Buscando reutilización para: Presupuesto gastos 2017
#  → Buscando reutilización para: Presupuesto de gasto en 2019
#  → Buscando reutilización para: Presupuesto de gasto en 2019
#  → Buscando reutilización para: Presupuesto de gasto en 2019
#  → Buscando reutilización para: Presupuesto de gasto en 2019
#  → Buscando reutilización para: Presupuesto de gasto en 2019
#  → Buscando reutilización para: Presupuesto de gasto en 2019
#  → Buscando reutilización para: Contratos menores CARM 2018
#  → Buscando reutilización para: Contratos menores CARM 2019
#  → Buscando reutilización para: Contratos CARM 2014 (Excluidos contratos menores)
#  → Buscando reutilización para: Presupuesto 2016 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Contratos CARM 2017 (Excluidos contratos menores)
#  → Buscando reutilización para: Presupuesto gastos 2018
#  → Buscando reutilización para: Concejalías del Ayuntamiento de Lorca
#  → Buscando reutilización para: Registro de Fundaciones de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Agenda de la Oficina de Congresos
#  → Buscando reutilización para: Corporación municipal
#  → Buscando reutilización para: Museos en la Región de Murcia
#  → Buscando reutilización para: Estructura económica del presupuesto 2023 de la CARM
#  → Buscando reutilización para: Estructura económica del presupuesto 2022 de la CARM
#  → Buscando reutilización para: Relación de puestos de trabajo de la Administración General y sus Organismos Autónomos
#  → Buscando reutilización para: Plan de Comunicación y Publicidad Institucional 2022
#  → Buscando reutilización para: Contratos 2022
#  → Buscando reutilización para: Restaurantes
#  → Buscando reutilización para: Inmuebles Municipales
#  → Buscando reutilización para: Agenda de la ciudad de Cartagena
#  → Buscando reutilización para: Contratos 2015
#  → Buscando reutilización para: Programas Educativos, Concejalía de Educación
#  → Buscando reutilización para: Plan Anual Normativo 2018
#  → Buscando reutilización para: Acuerdos Municipales del Ayuntamiento de Cartagena
#  → Buscando reutilización para: Censo de Actividades Económicas por Epígrafe
#  → Buscando reutilización para: Contratos 2016
#  → Buscando reutilización para: Estadística del número de contratos mayores por trimestres
#  → Buscando reutilización para: Smart5k - Flujos de circulación de vehículos - Agregado - Pliego
#  → Buscando reutilización para: Smart5k – Flujos de circulación de vehículos - Pliego
#  → Buscando reutilización para: Índices del Boletín Oficial de la Región de Murcia. Ejercicio 2009
#  → Buscando reutilización para: Convenios de Colaboración suscritos desde el año 2014
#  → Buscando reutilización para: Estadística de convenios de la CARM por tipo y ejercicio
#  → Buscando reutilización para: Smart5k – Flujos de circulación de vehículos - Albudeite
#  → Buscando reutilización para: Smart5k - Flujos de circulación de vehículos - Agregado - Albudeite
#  → Buscando reutilización para: Contratos 2019
#  → Buscando reutilización para: Datos contextuales de calidad del aire - ODALA
#  → Buscando reutilización para: Proveedores más importantes del Ayuntamiento de San Javier 2020
#  → Buscando reutilización para: Contrataciones en publicidad institucional de la CARM
#  → Buscando reutilización para: Bienes Inmuebles de la Comunidad Autónoma de la Región de Murcia. 2023
#  → Buscando reutilización para: Bienes Inmuebles de la Comunidad Autónoma de la Región de Murcia. 2021
#  → Buscando reutilización para: Noticias de la CARM en los últimos 7 días
#  → Buscando reutilización para: Noticias de la Concejalía de Juventud
#  → Buscando reutilización para: Estadística del número de contratos mayores por tipo y ejercicio
#  → Buscando reutilización para: Estadística del número de contratos mayores por tipo y trimestres
#  → Buscando reutilización para: Evolución gasto por habitante, cama y estancia
#  → Buscando reutilización para: Previsiones informativas de Altos cargos de la CARM en los últimos siete días
#  → Buscando reutilización para: Evolución de las defunciones según municipio de residencia
#  → Buscando reutilización para: Noticias
#  → Buscando reutilización para: Contratos menores CARM 2021
#  → Buscando reutilización para: Fiestas
#  → Buscando reutilización para: Índices del Boletín Oficial de la Región de Murcia. Ejercicio 1991
#  → Buscando reutilización para: Actualidad del Ayuntamiento de Cartagena
#  → Buscando reutilización para: Contratos menores CARM 2023
#  → Buscando reutilización para: Subvenciones a la Enseñanza Concertada en la Comunidad Autónoma de la Región de Murcia desde 2019
#  → Buscando reutilización para: Índices del Boletín Oficial de la Región de Murcia. Ejercicio 1996
#  → Buscando reutilización para: Lugares de Interés
#  → Buscando reutilización para: Solicitudes de Derecho de Acceso a la Información Pública del ejercicio 2021
#  → Buscando reutilización para: Contratos menores CARM 2022
#  → Buscando reutilización para: Presupuesto 2015 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Vacunaciones. Cobertura vacunal.
#  → Buscando reutilización para: Presupuesto 2017 de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Contratos menores CARM 2020
#  → Buscando reutilización para: Presupuesto gastos 2013
#  → Buscando reutilización para: Presupuesto gastos 2014
#  → Buscando reutilización para: Presupuesto gastos 2016
#  → Buscando reutilización para: Contratos 2020
#  → Buscando reutilización para: Contratos 2021
#  → Buscando reutilización para: Equipos Informáticos de escritorio de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Facturas desde el 01/01/2015
#  → Buscando reutilización para: Contratos 2017
#  → Buscando reutilización para: Perfil contratante 2015
#  → Buscando reutilización para: Perfil del contratante en 2016
#  → Buscando reutilización para: Contratos CARM 2018 (Excluidos contratos menores)
#  → Buscando reutilización para: Actividades Lorcajoven
#  → Buscando reutilización para: Bibliotecas
#  → Buscando reutilización para: Asociaciones culturales y tradiciones populares
#  → Buscando reutilización para: Contratos menores 2016
#  → Buscando reutilización para: Centros de Salud
#  → Buscando reutilización para: Salud Mental. Centros de salud mental y centros de atención a drogodependientes según municipios
#  → Buscando reutilización para: Consultas en áreas de Salud CARM
#  → Buscando reutilización para: Convenios del Servicio Murciano de Salud
#  → Buscando reutilización para: Cuidados Paliativos. Dispositivos según áreas de salud
#  → Buscando reutilización para: Evolución de la población por áreas de salud.
#  → Buscando reutilización para: Evolución de la población de la Región de Murcia según zonas básicas de salud, municipio y área de salud.
#  → Buscando reutilización para: Salud mental. Evolución de los recursos humanos según tipo
#  → Buscando reutilización para: Centros de Salud y consultorios de la Región de Murcia
#  → Buscando reutilización para: Atención Primaria. Personal según estamento profesional y áreas de salud.
#  → Buscando reutilización para: Coste sindical del Servicio Murciano de Salud. Ejercicio 2023
#  → Buscando reutilización para: Coste sindical del Servicio Murciano de Salud. Ejercicio 2022
#  → Buscando reutilización para: Coste sindical del Servicio Murciano de Salud. Ejercicio 2021
#  → Buscando reutilización para: Coste sindical del Servicio Murciano de Salud. Ejercicio 2020
#  → Buscando reutilización para: Evolución de los equipos de atención primaria según áreas de salud
#  → Buscando reutilización para: Atención Primaria. Zonas básicas y áreas de salud a las que pertenece cada municipio
#  → Buscando reutilización para: Atención Primaria. Balance de los recursos adscritos al mapa sanitario según áreas de salud
#  → Buscando reutilización para: Tasas de profesionales sanitarios por población
#  → Buscando reutilización para: Ratio de población asignada por tipo de profesional
#  → Buscando reutilización para: Atención Primaria. Población asignada a profesionales
#  → Buscando reutilización para: Frecuentación a consultas en atención primaria CARM
#  → Buscando reutilización para: Farmacias. Evolución del número de establecimientos según municipios
#  → Buscando reutilización para: Enfermedades de declaración obligatoria. Evolución del número de casos registrados
#  → Buscando reutilización para: Enfermedades de declaración obligatoria. Número de casos registrados según municipios
#  → Buscando reutilización para: Recursos humanos para cuidados paliativos
#  → Buscando reutilización para: Población asignada a equipos de atención primaria
#  → Buscando reutilización para: Consumo farmaceútico CARM
#  → Buscando reutilización para: Contratos de emergencia del SMS durante el periodo de Alarma por COVID-19
#  → Buscando reutilización para: Spas
#  → Buscando reutilización para: Balnearios
#  → Buscando reutilización para: Evolución de las camas en funcionamiento en los hospitales por 1000 habitantes según dependencia
#  → Buscando reutilización para: Atención Especializada. Evolución de la dotación en los hospitales según dependencia
#  → Buscando reutilización para: Evolución de la dotación en funcionamiento en los hospitales según dependencia
#  → Buscando reutilización para: Atención Especializada. Evolución del número de hospitales según dependencia y tipo de centro
#  → Buscando reutilización para: Vacunaciones. Dosis administradas por municipio
#  → Buscando reutilización para: Centros de Talasoterapia
#  → Buscando reutilización para: Cobertura vacunal según municipios
#  → Buscando reutilización para: Personal sanitario según categorías
#  → Buscando reutilización para: Actividad obstrética en hospitales
#  → Buscando reutilización para: Frecuentación de urgencias en hospitales
#  → Buscando reutilización para: Indicadores básicos en hospitales CARM
#  → Buscando reutilización para: Recursos sanitarios por 100 camas en funcionamiento
#  → Buscando reutilización para: Urgencias atendidas en hospitales
#  → Buscando reutilización para: Vacunas en niños por municipio
#  → Buscando reutilización para: Consultorios Médicos
#  → Buscando reutilización para: Evolución inversión por habitante, cama y estancia
#  → Buscando reutilización para: Consultas totales en hospitales CARM
#  → Buscando reutilización para: Compras y gastos en los hospitales según dependencia. ECSAE.
#  → Buscando reutilización para: Recursos sanitarios por 1000 habitantes
#  → Buscando reutilización para: Evolución actos quirúrgicos CARM
#  → Buscando reutilización para: Profesionales sanitarios colegiados. Evolución por disciplina
#  → Buscando reutilización para: Estancias según áreas asistenciales CARM
#  → Buscando reutilización para: Estancias medias según áreas asistenciales
#  → Buscando reutilización para: Evolución del presupuesto inicial de gasto sanitario
#  → Buscando reutilización para: Tasas de consultas totales en hospitales CARM
#  → Buscando reutilización para: volución de la actividad asistencial en los hospitales CARM
#  → Buscando reutilización para: Vacunaciones en niños
#  → Buscando reutilización para: Vacunaciones. Número de dosis administradas CARM
#  → Buscando reutilización para: Conciertos sanitarios con entidades privadas
#  → Buscando reutilización para: Recursos humanos para urgencias extrahospitalarias CARM
#  → Buscando reutilización para: Tasas de pacientes dados de alta según áreas asistenciales
#  → Buscando reutilización para: Evolución de pacientes por áreas asistenciales CARM
#  → Buscando reutilización para: Hospitales
#  → Buscando reutilización para: Profesionales sanitarios colegiados. Evolución por disciplina, edad, sexo
#  → Buscando reutilización para: Profesionales sanitarios colegiados. Evolución por disciplina, situacion laboral y sexo
#  → Buscando reutilización para: Coste sindical en la Comunidad Autónoma de la Región de Murcia para ejercicio 2019
#  → Buscando reutilización para: Coste sindical en la Comunidad Autónoma de la Región de Murcia para ejercicio 2018
#  → Buscando reutilización para: Coste sindical en la Comunidad Autónoma de la Región de Murcia para ejercicio 2016
#  → Buscando reutilización para: Coste sindical en la Comunidad Autónoma de la Región de Murcia para ejercicio 2015
#  → Buscando reutilización para: Contratos CARM 2016 (Excluidos contratos menores)
#  → Buscando reutilización para: Centros de Educación Infantil y Primaria (Privados)
#  → Buscando reutilización para: Centros de Educación Infantil y Primaria (Concertados)
#  → Buscando reutilización para: Centros de Educación Infantil y Primaria (Públicos)
#  → Buscando reutilización para: Centros de Educación Infantil 0-3 años
#  → Buscando reutilización para: Institutos de Educación Secundaria Obligatoria, Bachillerato y FP
#  → Buscando reutilización para: Evolución de centros que imparten Educación Especial y alumnado matriculado
#  → Buscando reutilización para: Listado de Centros Educativos
#  → Buscando reutilización para: Retribuciones por conceptos del personal docente no universitario para el ejercicio 2017
#  → Buscando reutilización para: Evolución del alumnado matriculado según enseñanza y titularidad del centro
#  → Buscando reutilización para: Evolución del número de unidades/grupos según enseñanza y titularidad
#  → Buscando reutilización para: Evolución de centros según enseñanza y titularidad.Régimen General y Adultos
#  → Buscando reutilización para: Evolución del alumnado extranjero según enseñanza y titularidad
#  → Buscando reutilización para: Evolución del alumnado con necesidades educativas especiales integrado
#  → Buscando reutilización para: Retribuciones por conceptos del personal docente no universitario para el ejercicio 2018
#  → Buscando reutilización para: Cursos de Español
#  → Buscando reutilización para: Evolución de centros educativos según las enseñanzas que imparten y titularidad
#  → Buscando reutilización para: Evolución del número de centros, Enseñanzas de Régimen General y Adultos
#  → Buscando reutilización para: Evolución del profesorado en Enseñanzas de Régimen General. Centros públicos
#  → Buscando reutilización para: Evolución del alumnado extranjero según nacionalidad y titularidad, por régimen de enseñanza
#  → Buscando reutilización para: Evolución del profesorado en Enseñanzas de Régimen General. Centros privados
#  → Buscando reutilización para: Evolución de centros según enseñanza y titularidad.Régimen Especial
#  → Buscando reutilización para: Evolución del profesorado según titularidad, clase de centro y sexo
#  → Buscando reutilización para: Evolución del alumnado matriculado según municipio y titularidad, por enseñanza
#  → Buscando reutilización para: Evolución del profesoradosegún municipio, por cuerpo/categoría. Centros públicos.
#  → Buscando reutilización para: Evolución del profesoradosegún municipio, por cuerpo/categoría. Centros privados
#  → Buscando reutilización para: Evolución del profesorado según municipio y titularidad, por clase de centro
#  → Buscando reutilización para: Evolución del alumnado que terminó los estudios según enseñanza y titularidad del centro
#  → Buscando reutilización para: Evolución del número de unidades/grupos en Enseñanzas de Régimen General
#  → Buscando reutilización para: Evolución del número de centros. Enseñanzas de Régimen Especial
#  → Buscando reutilización para: Evolución del número de centros educativos según municipio y titularidad, por clase de centro
#  → Buscando reutilización para: Noticias de Actualidad de la Universidad Popular
#  → Buscando reutilización para: Sedes de los Centros Educativos de la Región de Murcia
#  → Buscando reutilización para: Colegios en Lorca
#  → Buscando reutilización para: Asociaciones de padres y madres de alumnos
#  → Buscando reutilización para: Subvenciones a la Enseñanza Concertada en la Comunidad Autónoma de la Región de Murcia 2010-2018
#  → Buscando reutilización para: Solicitudes de Derecho de Acceso a la Información Pública del ejercicio 2018
#  → Buscando reutilización para: Solicitudes de Derecho de Acceso a la Información Pública del ejercicio 2020
#  → Buscando reutilización para: Cartas de servicios y compromisos de calidad de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Solicitudes de Derecho de Acceso a la Información Pública del ejercicio 2019
#  → Buscando reutilización para: Solicitudes de Derecho de Acceso a la Información Pública del ejercicio 2022
#  → Buscando reutilización para: Convenios
#  → Buscando reutilización para: Solicitudes de Derecho de Acceso a la Información Pública del ejercicio 2017
#  → Buscando reutilización para: Inventario de Altos Cargos de la CARM
#  → Buscando reutilización para: Contratos CARM 2015 (Excluidos contratos menores)
#  → Buscando reutilización para: Estructura funcional del presupuesto 2023 de la CARM
#  → Buscando reutilización para: Estructura funcional del presupuesto 2022 de la CARM
#  → Buscando reutilización para: Registro de Actividades de Tratamiento
#  → Buscando reutilización para: Sedes administrativas de la Administración Regional y su Sector Público
#  → Buscando reutilización para: Direciones y teléfonos
#  → Buscando reutilización para: Servicios del Ayuntamiento de Lorca
#  → Buscando reutilización para: Premios y concursos Lorcajoven
#  → Buscando reutilización para: Presupuesto Ingresos 2023 de la CA de la Región de Murcia
#  → Buscando reutilización para: Asociaciones
#  → Buscando reutilización para: Perfil del contratante 2014
#  → Buscando reutilización para: Presupuesto Ingresos 2022 de la CA de la Región de Murcia
#  → Buscando reutilización para: Registro de sociedades cooperativas de la Región de Murcia
#  → Buscando reutilización para: Distribución de personal público de la CARM por sectores y sexo
#  → Buscando reutilización para: Estadística de Altos Cargos por Consejería
#  → Buscando reutilización para: Presupuesto ingresos 2015
#  → Buscando reutilización para: Presupuesto ingresos 2016
#  → Buscando reutilización para: Presupuesto ingresos 2018
#  → Buscando reutilización para: Presupuesto ingresos 2014
#  → Buscando reutilización para: Presupuesto ingresos 2013
#  → Buscando reutilización para: Presupuesto ingresos 2019
#  → Buscando reutilización para: Presupuesto ingresos 2017
#  → Buscando reutilización para: Presupuesto ingresos 2017
#  → Buscando reutilización para: Presupuesto ingresos 2019
#  → Buscando reutilización para: Presupuesto ingresos 2017
#  → Buscando reutilización para: Contratos menores 2015
#  → Buscando reutilización para: Contratos menores 2013
#  → Buscando reutilización para: Asociaciones de defensa del medio ambientes
#  → Buscando reutilización para: Informe meteorológico de datos medios para el día en curso
#  → Buscando reutilización para: Registro General de Entidades de Voluntariado de la Región de Murcia
#  → Buscando reutilización para: Espacios Naturales
#  → Buscando reutilización para: Vehículos Inventariados
#  → Buscando reutilización para: Normativa Municipal
#  → Buscando reutilización para: Oficinas de Turismo
#  → Buscando reutilización para: Estructura orgánica del presupuesto 2022 de la CARM
#  → Buscando reutilización para: Estructura orgánica del presupuesto 2023 de la CARM
#  → Buscando reutilización para: Empleo privado
#  → Buscando reutilización para: Contratos menores 2014
#  → Buscando reutilización para: Adjudicatarios y contratistas más importantes del Ayuntamiento de San Javier 2019
#  → Buscando reutilización para: Proveedores más importantes del Ayuntamiento de San Javier 2019
#  → Buscando reutilización para: Adjudicatarios y contratistas más importantes del Ayuntamiento de San Javier 2020
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2023.
#  → Buscando reutilización para: Perfil del contratante 2018
#  → Buscando reutilización para: Monumentos en la Región de Murcia
#  → Buscando reutilización para: Proveedores más importantes del Ayuntamiento de San Javier 2018
#  → Buscando reutilización para: Adjudicatarios y contratistas más importantes del Ayuntamiento de San Javier 2018
#  → Buscando reutilización para: Centros de Interpretación
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2016.
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2015.
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2018.
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2017.
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2019
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2021
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2022.
#  → Buscando reutilización para: Estadísticas de solicitudes de acceso a información pública. Ejercicio 2020.
#  → Buscando reutilización para: Elecciones Municipales. Evolución de la participación por municipios
#  → Buscando reutilización para: Ayudas y subvenciones Lorcajoven
#  → Buscando reutilización para: Inventario de Vehículos
#  → Buscando reutilización para: Elecciones Municipales. Principales resultados
#  → Buscando reutilización para: Perfil del contratante 2017
#  → Buscando reutilización para: Sociedades Agrarias de Transformación
#  → Buscando reutilización para: Apartamentos Turísticos
#  → Buscando reutilización para: Emisiones de gases de efecto invernadero en la Región de Murcia
#  → Buscando reutilización para: Calidad del aire. Molina de Segura. Medidas de sensores 2021
#  → Buscando reutilización para: Inventario de Montes de la Comunidad Autónoma de la Región de Murcia
#  → Buscando reutilización para: Elecciones Municipales. Concejales por partidos y por municipios
#  → Buscando reutilización para: Calidad del aire. Molina de Segura. Medidas de sensores 2022
#  → Buscando reutilización para: Elecciones Autonómicas. Evolución de la participación por municipios
#  → Buscando reutilización para: Normativa Municipal
#  → Buscando reutilización para: Elecciones Autonómicas. Principales resultados
#  → Buscando reutilización para: Elecciones al Parlamento Europeo. Participación y votos obtenidos por partidos políticos
#  → Buscando reutilización para: Elecciones al Parlamento Europeo. Evolución de la participación según municipios
#  → Buscando reutilización para: Elecciones Autonómicas. Principales resultados por municipios
#  → Buscando reutilización para: Elecciones Autonómicas. Composición de la Asamblea Regional
#  → Buscando reutilización para: Centros de la Naturaleza
#  → Buscando reutilización para: Smart5K – Riego inteligente - Pliego
#  → Buscando reutilización para: Smart5k - Climatología - Ulea
#  → Buscando reutilización para: Smart5k - Climatología - Ricote
#  → Buscando reutilización para: Smart5k - Climatología - Ojós
#  → Buscando reutilización para: Smart5k - Calidad del aire - ICA - RICOTE
#  → Buscando reutilización para: Smart5k - Calidad del aire - ICA - OJOS
#  → Buscando reutilización para: Smart5k - Calidad del aire - ICA - ULEA
#  → Buscando reutilización para: Datos históricos de Calidad del Aire - Gases - ODALA
#  → Buscando reutilización para: Smart5k - Nivel de Ruido - Ojos
#  → Buscando reutilización para: Smart5k - Nivel de Ruido - Ricote
#  → Buscando reutilización para: Smart5k - Nivel de Ruido - Ulea
#  → Buscando reutilización para: Rutas turísticas por la naturaleza
#  → Buscando reutilización para: Smart5k - Automatización de riego - Electroválvula - Albudeite
#  → Buscando reutilización para: Smart5k - Automatización de riego - Climatología - Albudeite
#  → Buscando reutilización para: Smart5k - Conteo de personas - Ulea
#  → Buscando reutilización para: Smart5k - Conteo de personas - Ricote
#  → Buscando reutilización para: Smart5k - Conteo de personas - Ojos
#  → Buscando reutilización para: Smart5k - Conteo de personas - Villanueva
#  → Buscando reutilización para: Smart5k - Nivel de Ruido - Villanueva
#  → Buscando reutilización para: Smart5k - Calidad del aire - Gases y materia particulada - Ojos
#  → Buscando reutilización para: Smart5k - Calidad del aire - Gases y materia particulada - Ulea
#  → Buscando reutilización para: Smart5k - Calidad del aire - Gases y materia particulada - Villanueva
#  → Buscando reutilización para: Estadística nacimientos de habitantes
#  → Buscando reutilización para: Estadística de defunciones de habitantes
#  → Buscando reutilización para: Extensión de barrios casco urbano
#  → Buscando reutilización para: Estadística altas de residencia
#  → Buscando reutilización para: Estadística habitantes por pedanías y sexo
#  → Buscando reutilización para: Estadística habitantes por nacionalidad y sexo
#  → Buscando reutilización para: Estadística habitantes por edad y sexo
#  → Buscando reutilización para: Callejero con secciones censales
#  → Buscando reutilización para: Callejero con núcleos de población
#  → Buscando reutilización para: Extensión de las pedanías y casco urbano
#  → Buscando reutilización para: Estadística habitantes por nacionalidad y sexo
#  → Buscando reutilización para: Estadística habitantes por barrio y sexo
#  → Buscando reutilización para: Estadística habitantes por distrito sección y sexo
#  → Buscando reutilización para: Estadística bajas de residencia
#  → Buscando reutilización para: Callejero con entidades de población
#  → Buscando reutilización para: Censo electoral por mesas (Elecciones Generales 2016)
#  → Buscando reutilización para: Estadística de habitantes por año de nacimiento y sexo
#  → Buscando reutilización para: Barrios
#  → Buscando reutilización para: Censo electoral por mesas (Elecciones Generales 2015)
#  → Buscando reutilización para: Estadística de densidad de población en pedanias y casco urbano
#  → Buscando reutilización para: Estadística de densidad de población por barrios
#  → Buscando reutilización para: Estadística de densidad de población por barrios
#  → Buscando reutilización para: Estadística habitantes por edad, sexo y distrito
#  → Buscando reutilización para: Población a 1 de enero de 2016 (por edad y sexo)
#  → Buscando reutilización para: Población a 1 de enero de 2016 por Barrio
#  → Buscando reutilización para: Población a 1 de enero de 2016 por Calle
#  → Buscando reutilización para: Población a 1 de enero de 2016 por Nacionalidad
#  → Buscando reutilización para: Población a 1 de enero de 2016 por Sección
#  → Buscando reutilización para: Población a 1 de enero de 2016 por Entidad
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2018
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2017
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2016
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2015
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2015
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2015
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2012
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2013
#  → Buscando reutilización para: Padrón municipal de habitantes, por nacionalidad y sexo 2014
#  → Buscando reutilización para: Población a 1 de enero de 2016 por País de Nacimiento
#  → Buscando reutilización para: Población a 1 de enero de 2016 por Entidad y Núcleo
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos edad, sexo y distrito 2018
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos edad, sexo y distrito 2017
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos edad, sexo y distrito 2016
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos edad, sexo y distrito 2015
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos de edad y sexo 2018
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos de edad y sexo 2017
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos de edad y sexo 2016
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos de edad y sexo 2015
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos de edad y sexo 2012
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos de edad y sexo 2013
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos de edad y sexo 2014
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos edad, sexo y distrito 2012
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos edad, sexo y distrito 2013
#  → Buscando reutilización para: Padrón municipal de habitantes, por grupos edad, sexo y distrito 2014
#  → Buscando reutilización para: Evolución de los saldos migratorios con otras provincias por municipio
#  → Buscando reutilización para: Evolución de los saldos migratorios con otras provincias por provincias
#  → Buscando reutilización para: Evolución de la población de la Región de Murcia según entidades.
#  → Buscando reutilización para: Evolución de las defunciones según nacionalidad
#  → Buscando reutilización para: Evolución de los saldos migratorios dentro de España
#  → Buscando reutilización para: Evolución de las emigraciones totales según municipio de procedencia
#  → Buscando reutilización para: Evolución de los saldos migratorios totales según municipio, por nacionalidad
#  → Buscando reutilización para: Evolución de la población extranjera de la Región de Murcia según municipios
#  → Buscando reutilización para: Evolución de la población de la Región de Murcia según municipios
#  → Buscando reutilización para: Evolución de los saldos migratorios entre municipios de la Región de Murcia
#  → Buscando reutilización para: Evolución de las inmigraciones totales según municipio de destino
#  → Buscando reutilización para: Evolución de las inmigraciones según nacionalidad y procedencia
#  → Buscando reutilización para: Evolución de la población de la Región de Murcia según sexo y edad
#  → Buscando reutilización para: Evolución de la población de la Región de Murcia según nacionalidad
#  → Buscando reutilización para: Evolución de la población extranjera en la Región de Murcia según entidades
#  → Buscando reutilización para: Indicadores demográficos de nacimientos en la Región de Murcia
#
# ✅ Archivo generado correctamente → Punto2_Murcia_reutilizacion_V3 DEFINITIVO2.xlsx
#
# 📊 Recuento de huellas de reutilización REAL (filtradas) – Región de Murcia:
#
#   crossref: 9498 coincidencias
#   zenodo: 5660 coincidencias
#   openalex: 1033 coincidencias
